# %%
ls
# Out:
# __pycache__/  logs/  magics.py  proxy.py  scala_magic.py

# %%
# !pwd
# Out:
# /opt/tiger/studio

# %%
# !pwd
# Out:
# /opt/tiger/studio

# %%
ls
# Out:
# __pycache__/  logs/  magics.py  proxy.py  scala_magic.py
