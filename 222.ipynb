# %%
ls
# Out:
# __pycache__/  logs/  magics.py  proxy.py  scala_magic.py

# %%
ls
# Out:
# __pycache__/  logs/  magics.py  proxy.py  scala_magic.py

# %%
from time  import sleep

import json
sleep(5)
print(1)
print(1)

print(1)
print(1)
print(1)
print(1)
print(1)
print(1)
content = '我是一个小朋友'

print(json.dumps(content, indent=1))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# "\u6211\u662f\u4e00\u4e2a\u5c0f\u670b\u53cb"
